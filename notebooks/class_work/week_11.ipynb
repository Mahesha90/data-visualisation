# %%
number=3+7;
print("The total is:", +number)
# Out:
# The total is: 10

# %%
Name = "Mahesha" # If it is a string we need to write inside the double quotes.
print("Hello " +Name)
# Out:
# Hello Mahesha

# %%
for no in range(5): 
    print(no)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for letter in Name:
    print(letter)
    #"Mahesha" is inside the double quotes. Python autmatically understand this as a string (Text). 
    # Strings in Python are iteratable
# Out:
# M
# a
# h
# e
# s
# h
# a

# %%
age = 20
if age <=7: print("Free")
else: print("Buy a ticket")
if age <18: print("Child ticket")
else: print("adult ticket")
# Out:
# Buy a ticket
# adult ticket

# %%
sentence = "racecarlevelfield"

# extract first 3 letters
print("Print first 3 letters:", sentence[0:3]) #start: end
print(sentence[:3])
# Extract letters from 5-9
print(sentence[5:9])
#Extract letters from 5th to end
print(sentence[5:])
#Extract the last character
print(sentence[-1])
#Extract last 4 characters
print(sentence[-4:])
#extract first letter of the substring starting from 5
#sentence[5:]: will extract a substring starting from 5
#[0]: this will takes the first character of that substring
print(sentence[5:][0])
#Extract first 5 letters of the substring starting from 5
print(sentence[5:][:5])
#Extract entire String/Text
print(sentence[:])
#Extract every 2nd character
print(sentence[::2])
# Out:
# Print first 3 letters: rac
# rac
# arle
# arlevelfield
# d
# ield
# a
# arlev
# racecarlevelfield
# rccreefed

# %%
sentence = "Alice went to the park and saw a beautiful bird singing"

words = sentence.split(" ") #Spliit the sentence to words

print(words)
#Extract first word
print(words[0])
#Extract the first 3 words
print(*words[0:3])
#Extract last 3 words
print(words[-3:])
#Print number of words
print("The number of words :", len(words))
# Out:
# ['Alice', 'went', 'to', 'the', 'park', 'and', 'saw', 'a', 'beautiful', 'bird', 'singing']
# Alice
# Alice went to
# ['beautiful', 'bird', 'singing']
# The number of words : 11

# %%
pip install wordcloud #This is the library we are using work wordcloud
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

wc = WordCloud().generate("rain rain rain brings hope hope")

img =wc.to_image()
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
import urllib.request #This one we use to work with URLs

text = urllib.request.urlopen("").read().decode("utf-8")
